# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("KNN Clustering.csv")

# %%
data.head(3)
# Out:
#    sepal_lenght  sepal_width  petal_length  petal_width
# 0           3.2          3.5           1.4          0.3
# 1           3.1          2.3           1.3          0.3
# 2           3.4          1.2           1.4          2.0

# %%
sns.pairplot(data=data)
plt.show()

# %%
import scipy.cluster.hierarchy as sc

# %%
plt.figure.figsize=(10,10)
sc.dendrogram(sc.linkage(data,method='single',metric='euclidean'))
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ac = AgglomerativeClustering(n_clusters=2,linkage='single')
data["Predict"] = ac.fit_predict(data)

# %%
data.head(2)
# Out:
#    sepal_lenght  sepal_width  petal_length  petal_width  Predict
# 0           3.2          3.5           1.4          0.3        0
# 1           3.1          2.3           1.3          0.3        0

# %%
sns.pairplot(data=data,hue="Predict")
plt.show()
